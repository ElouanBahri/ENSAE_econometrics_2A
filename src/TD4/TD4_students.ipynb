# %% [markdown]
# # Econometrics 1

# %% [markdown]
# ## TD 4 - 17/10/2024

# %% [markdown]
# TA: Pedro Vergara Merino ([pedro.vergaramerino@ensae.fr](mailto:pedro.vergaramerino@ensae.fr), office 4081)

# %%
# Install packages
if(!require(haven)) install.packages("haven")  
if(!require(car)) install.packages("car")
if(!require(estimatr)) install.packages("estimatr")  
if(!require(lmtest)) install.packages("lmtest")

#Load packages
library(haven)
library(car)
library(estimatr)
library(lmtest)
# Out:
# Error in setwd("Your path"): impossible de changer de répertoire de travail
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "impossible de changer de répertoire de travail", base::quote(setwd("Your path")))
